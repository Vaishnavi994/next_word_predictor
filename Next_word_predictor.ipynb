# %%
faqs="""PROGRAM OUTCOMES (POS)
PO1: Engineering Knowledge: Apply knowledge of mathematics, science,
engineering fundamentals and an engineering specialization to the solution complex
engineering problems.
PO2: Problem Analysis: Identify, formulate, research literature and analyze complex
engineering problems reaching substantiated conclusions using first principles of
mathematics, natural sciences and engineering sciences.
PO3: Design/ Development of Solutions: Design solutions for complex engineering
problems and design system components or processes that meet specified needs
with appropriate consideration for public health and safety, cultural, societal and
environmental considerations.
PO4: Conduct investigations of complex problems:Use research-based knowledge
and research methods including design of experiments, analysis and interpretation
of data and synthesis of information to provide valid conclusions.
PO5: Modern Tool Usage: Create, select and apply appropriate techniques,
resources and modern engineering and IT tools including prediction and modeling to
complex engineering activities with an understanding of the limitations.
PO6: The Engineer and Society:Apply reasoning informed by contextual knowledge
to assess societal, health, safety, legal and cultural issues and the consequent
responsibilities relevant to professional engineering practice.
PO7:  Environment and Sustainability: Understand the impact of professional
engineering solutions in societal and environmental contexts and demonstrate
knowledge of and need for sustainable development.
PO8: Ethics:Apply ethical principles and commit to professional ethics and
responsibilities and norms of engineering practice.
PO9: Individual and Team Work:Function effectively as an individual, and as a
member or leader in diverse teams and in multi-disciplinary settings.
PO10: Communication: Communicate effectively on complex engineering activities
with the engineering community and with society at large, such as being able to
comprehend and write effective reports and design documentation, make effective
presentations and give and receive clear instructions.
PO11: Project Management and Finance:Demonstrate knowledge and
understanding of engineering and management principles and apply these to one’s
own work, as a member and leader in a team, to manage projects and in
multidisciplinary environments.
PO12: Life-long Learning:Recognize the need for and have the preparation and
ability to Engage in independent and life- long learning in the broadest context of
technological Change.
PROGRAM SPECIFIC OUTCOMES (PSOs)
PSO1: To collect requirements, analyze, design, implement and test software
Systems.
PSO2:To analyze the errors and debug them within minimal time.
COURSE OVERVIEW:
Advanced Data Structures Laboratory course is to improve the programming skills using
CLanguage.This course covers implementing applications of linked lists and queues.
Thiscourse also enables to implement search trees and graphs , dictionaries and
hashing.Thecourse also enables to implementadvanced search tress and text processing.
After the completion of this course student will be able to implement efficient algorithm for
a software.

COURSE OUTCOMES (COs)

After the completion of the course, the student will be able to:
CO#  Course Outcomes
A8513.1  Implement programs using linear data structures to process data.
A8513.2 Implement operations on non-linear data structures for handling large data.
A8513.3 Build traversal algorithms for efficient search on nonlinear data structures.
A8513.4 Develop algorithms for text processing applications.
Circular Linked Lists: Circular Linked Lists are an extension of the traditional
linked list data structure. In this variant, the last node in the list points back
to the first node, forming a circular loop. This arrangement facilitates
seamless traversal from any point in the list to any other point, making it
particularly useful for scenarios where cyclic operations or continuous data
processing is required. Circular Linked Lists find applications in tasks such as
managing resources in a round-robin scheduling system or representing
cyclic structures in real-world scenarios.
Circular Queue using Linked List: A Circular Queue is a data structure that
follows the First-In-First-Out (FIFO) principle. When implemented with a
linked list, it allows for efficient management of a dynamic collection of
elements. The circular arrangement eliminates the need to shift elements
during enqueue and dequeue operations, providing a more optimized
solution. Circular Queues are employed in scenarios where a continuous
flow of data is desired, such as in network traffic buffering or job scheduling
in operating systems.
Deque using Linked List: Deque, short for double-ended queue, is a
versatile data structure that supports insertion and deletion at both ends.
When implemented with a linked list, it offers flexibility in managing data at
the front and rear ends efficiently. Deques find applications in situations
where dynamic and bidirectional data manipulation is essential, such as in
undo mechanisms in applications or managing a sliding window of data in
algorithms.
Addition of Two Polynomials: Polynomial addition involves combining like
terms from two polynomials by adding coefficients corresponding to the
same power of the variable. This operation is fundamental in algebraic
computations, including signal processing and cryptography. Implementing
polynomial addition efficiently is crucial for handling large datasets and
complex mathematical expressions.
Multiplication of Two Polynomials: Polynomial multiplication is the process
of multiplying each term of one polynomial by every term of the other. Thisoperation is pivotal in diverse fields, including computer graphics, error
correction codes, and numerical simulations. Efficient implementation of
polynomial multiplication using data structures like linked lists is essential
for optimizing computational resources and ensuring accurate results.
Heap Sort: Heap Sort is a comparison-based sorting algorithm that
leverages a binary heap data structure. By creating a heap and repeatedly
extracting the maximum element, Heap Sort achieves efficient sorting with
a consistent time complexity. This algorithm is widely used in scenarios
where a stable sorting solution is not critical, such as in embedded systems
or real-time applications.
Binary Search Trees: Binary Search Trees are hierarchical data structures
where each node has at most two children. The left child contains values
smaller than the node, while the right child contains values greater than the
node. Operations on Binary Search Trees include insertion, deletion,
searching, and traversal. These trees are employed in scenarios where
maintaining a sorted dataset and efficient search operations are paramount,
such as in database indexing or symbol tables in compilers.
Breadth First Search (BFS): Breadth First Search is a graph traversal
algorithm that explores all vertices at the current depth before moving on to
the next level. This algorithm is invaluable in applications such as social
network analysis, shortest path calculations, and network routing protocols.
BFS efficiently covers the breadth of a graph, making it suitable for scenarios
where a comprehensive exploration of the structure is required.
Depth First Search (DFS): Depth First Search is a graph traversal algorithm
that explores as far as possible along each branch before backtracking. DFS
is utilized in diverse applications, including maze solving, topological sorting,
and cycle detection in graphs. This algorithm provides insights into the
structure of a graph and is often chosen based on specific problem
requirements.

"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
#tokenizer converts text -> numbers

# %%
tokenizer=Tokenizer()

# %%
print(type(faqs))
# Out:
# <class 'str'>

# %%
tokenizer.fit_on_texts([faqs])
#list of strings and sorts by frequncy

# %%
tokenizer.word_index
# Out:
# {'and': 1,
#  'the': 2,
#  'in': 3,
#  'of': 4,
#  'a': 5,
#  'to': 6,
#  'is': 7,
#  'data': 8,
#  'engineering': 9,
#  'for': 10,
#  'as': 11,
#  'search': 12,
#  'linked': 13,
#  'first': 14,
#  'or': 15,
#  'this': 16,
#  'applications': 17,
#  'circular': 18,
#  'complex': 19,
#  'with': 20,
#  'such': 21,
#  'course': 22,
#  'structures': 23,
#  'algorithm': 24,
#  'list': 25,
#  'where': 26,
#  'knowledge': 27,
#  'using': 28,
#  'design': 29,
#  'that': 30,
#  'on': 31,
#  'efficient': 32,
#  'structure': 33,
#  'scenarios': 34,
#  'apply': 35,
#  'including': 36,
#  'it': 37,
#  'at': 38,
#  'implement': 39,
#  'lists': 40,
#  'trees': 41,
#  'operations': 42,
#  'traversal': 43,
#  'are': 44,
#  'node': 45,
#  'polynomial': 46,
#  'heap': 47,
#  'outcomes': 48,
#  'an': 49,
#  'problems': 50,
#  'by': 51,
#  'processing': 52,
#  'a8513': 53,
#  'two': 54,
#  'sorting': 55,
#  'binary': 56,
#  'graph': 57,
#  'solution': 58,
#  'analysis': 59,
#  'research': 60,
#  'analyze': 61,
#  'principles': 62,
#  'solutions': 63,
#  'societal': 64,
#  'based': 65,
#  'resources': 66,
#  'professional': 67,
#  'need': 68,
#  'diverse': 69,
#  'large': 70,
#  'able': 71,
#  'management': 72,
#  'systems': 73,
#  'time': 74,
#  'algorithms': 75,
#  'managing': 76,
#  'queue': 77,
#  'network': 78,
#  'efficiently': 79,
#  'addition': 80,
#  'polynomials': 81,
#  'multiplication': 82,
#  'each': 83,
#  'sort': 84,
#  'breadth': 85,
#  'depth': 86,
#  'program': 87,
#  'mathematics': 88,
#  'problem': 89,
#  'conclusions': 90,
#  'sciences': 91,
#  'development': 92,
#  'system': 93,
#  'appropriate': 94,
#  'health': 95,
#  'safety': 96,
#  'cultural': 97,
#  'environmental': 98,
#  'modern': 99,
#  'activities': 100,
#  'understanding': 101,
#  'society': 102,
#  'responsibilities': 103,
#  'practice': 104,
#  'demonstrate': 105,
#  'ethics': 106,
#  'individual': 107,
#  'team': 108,
#  'work': 109,
#  'effectively': 110,
#  'member': 111,
#  'leader': 112,
#  'effective': 113,
#  'these': 114,
#  'life': 115,
#  'long': 116,
#  'learning': 117,
#  'specific': 118,
#  'requirements': 119,
#  'software': 120,
#  'covers': 121,
#  'implementing': 122,
#  'queues': 123,
#  'also': 124,
#  'enables': 125,
#  'graphs': 126,
#  'text': 127,
#  'after': 128,
#  'completion': 129,
#  'student': 130,
#  'will': 131,
#  'be': 132,
#  'linear': 133,
#  'process': 134,
#  'handling': 135,
#  'arrangement': 136,
#  'from': 137,
#  'any': 138,
#  'point': 139,
#  'other': 140,
#  'making': 141,
#  'cyclic': 142,
#  'continuous': 143,
#  'required': 144,
#  'find': 145,
#  'scheduling': 146,
#  'real': 147,
#  'when': 148,
#  'implemented': 149,
#  'dynamic': 150,
#  'elements': 151,
#  'employed': 152,
#  'deque': 153,
#  'insertion': 154,
#  'deletion': 155,
#  'ends': 156,
#  'essential': 157,
#  'like': 158,
#  'term': 159,
#  'child': 160,
#  'contains': 161,
#  'values': 162,
#  'than': 163,
#  'bfs': 164,
#  'explores': 165,
#  'before': 166,
#  'dfs': 167,
#  'pos': 168,
#  'po1': 169,
#  'science': 170,
#  'fundamentals': 171,
#  'specialization': 172,
#  'po2': 173,
#  'identify': 174,
#  'formulate': 175,
#  'literature': 176,
#  'reaching': 177,
#  'substantiated': 178,
#  'natural': 179,
#  'po3': 180,
#  'components': 181,
#  'processes': 182,
#  'meet': 183,
#  'specified': 184,
#  'needs': 185,
#  'consideration': 186,
#  'public': 187,
#  'considerations': 188,
#  'po4': 189,
#  'conduct': 190,
#  'investigations': 191,
#  'use': 192,
#  'methods': 193,
#  'experiments': 194,
#  'interpretation': 195,
#  'synthesis': 196,
#  'information': 197,
#  'provide': 198,
#  'valid': 199,
#  'po5': 200,
#  'tool': 201,
#  'usage': 202,
#  'create': 203,
#  'select': 204,
#  'techniques': 205,
#  'tools': 206,
#  'prediction': 207,
#  'modeling': 208,
#  'limitations': 209,
#  'po6': 210,
#  'engineer': 211,
#  'reasoning': 212,
#  'informed': 213,
#  'contextual': 214,
#  'assess': 215,
#  'legal': 216,
#  'issues': 217,
#  'consequent': 218,
#  'relevant': 219,
#  'po7': 220,
#  'environment': 221,
#  'sustainability': 222,
#  'understand': 223,
#  'impact': 224,
#  'contexts': 225,
#  'sustainable': 226,
#  'po8': 227,
#  'ethical': 228,
#  'commit': 229,
#  'norms': 230,
#  'po9': 231,
#  'function': 232,
#  'teams': 233,
#  'multi': 234,
#  'disciplinary': 235,
#  'settings': 236,
#  'po10': 237,
#  'communication': 238,
#  'communicate': 239,
#  'community': 240,
#  'being': 241,
#  'comprehend': 242,
#  'write': 243,
#  'reports': 244,
#  'documentation': 245,
#  'make': 246,
#  'presentations': 247,
#  'give': 248,
#  'receive': 249,
#  'clear': 250,
#  'instructions': 251,
#  'po11': 252,
#  'project': 253,
#  'finance': 254,
#  'one’s': 255,
#  'own': 256,
#  'manage': 257,
#  'projects': 258,
#  'multidisciplinary': 259,
#  'environments': 260,
#  'po12': 261,
#  'recognize': 262,
#  'have': 263,
#  'preparation': 264,
#  'ability': 265,
#  'engage': 266,
#  'independent': 267,
#  'broadest': 268,
#  'context': 269,
#  'technological': 270,
#  'change': 271,
#  'psos': 272,
#  'pso1': 273,
#  'collect': 274,
#  'test': 275,
#  'pso2': 276,
#  'errors': 277,
#  'debug': 278,
#  'them': 279,
#  'within': 280,
#  'minimal': 281,
#  'overview': 282,
#  'advanced': 283,
#  'laboratory': 284,
#  'improve': 285,
#  'programming': 286,
#  'skills': 287,
#  'clanguage': 288,
#  'thiscourse': 289,
#  'dictionaries': 290,
#  'hashing': 291,
#  'thecourse': 292,
#  'implementadvanced': 293,
#  'tress': 294,
#  'cos': 295,
#  'co': 296,
#  '1': 297,
#  'programs': 298,
#  '2': 299,
#  'non': 300,
#  '3': 301,
#  'build': 302,
#  'nonlinear': 303,
#  '4': 304,
#  'develop': 305,
#  'extension': 306,
#  'traditional': 307,
#  'variant': 308,
#  'last': 309,
#  'points': 310,
#  'back': 311,
#  'forming': 312,
#  'loop': 313,
#  'facilitates': 314,
#  'seamless': 315,
#  'particularly': 316,
#  'useful': 317,
#  'tasks': 318,
#  'round': 319,
#  'robin': 320,
#  'representing': 321,
#  'world': 322,
#  'follows': 323,
#  'out': 324,
#  'fifo': 325,
#  'principle': 326,
#  'allows': 327,
#  'collection': 328,
#  'eliminates': 329,
#  'shift': 330,
#  'during': 331,
#  'enqueue': 332,
#  'dequeue': 333,
#  'providing': 334,
#  'more': 335,
#  'optimized': 336,
#  'flow': 337,
#  'desired': 338,
#  'traffic': 339,
#  'buffering': 340,
#  'job': 341,
#  'operating': 342,
#  'short': 343,
#  'double': 344,
#  'ended': 345,
#  'versatile': 346,
#  'supports': 347,
#  'both': 348,
#  'offers': 349,
#  'flexibility': 350,
#  'front': 351,
#  'rear': 352,
#  'deques': 353,
#  'situations': 354,
#  'bidirectional': 355,
#  'manipulation': 356,
#  'undo': 357,
#  'mechanisms': 358,
#  'sliding': 359,
#  'window': 360,
#  'involves': 361,
#  'combining': 362,
#  'terms': 363,
#  'adding': 364,
#  'coefficients': 365,
#  'corresponding': 366,
#  'same': 367,
#  'power': 368,
#  'variable': 369,
#  'operation': 370,
#  'fundamental': 371,
#  'algebraic': 372,
#  'computations': 373,
#  'signal': 374,
#  'cryptography': 375,
#  'crucial': 376,
#  'datasets': 377,
#  'mathematical': 378,
#  'expressions': 379,
#  'multiplying': 380,
#  'one': 381,
#  'every': 382,
#  'thisoperation': 383,
#  'pivotal': 384,
#  'fields': 385,
#  'computer': 386,
#  'graphics': 387,
#  'error': 388,
#  'correction': 389,
#  'codes': 390,
#  'numerical': 391,
#  'simulations': 392,
#  'implementation': 393,
#  'optimizing': 394,
#  'computational': 395,
#  'ensuring': 396,
#  'accurate': 397,
#  'results': 398,
#  'comparison': 399,
#  'leverages': 400,
#  'creating': 401,
#  'repeatedly': 402,
#  'extracting': 403,
#  'maximum': 404,
#  'element': 405,
#  'achieves': 406,
#  'consistent': 407,
#  'complexity': 408,
#  'widely': 409,
#  'used': 410,
#  'stable': 411,
#  'not': 412,
#  'critical': 413,
#  'embedded': 414,
#  'hierarchical': 415,
#  'has': 416,
#  'most': 417,
#  'children': 418,
#  'left': 419,
#  'smaller': 420,
#  'while': 421,
#  'right': 422,
#  'greater': 423,
#  'include': 424,
#  'searching': 425,
#  'maintaining': 426,
#  'sorted': 427,
#  'dataset': 428,
#  'paramount': 429,
#  'database': 430,
#  'indexing': 431,
#  'symbol': 432,
#  'tables': 433,
#  'compilers': 434,
#  'all': 435,
#  'vertices': 436,
#  'current': 437,
#  'moving': 438,
#  'next': 439,
#  'level': 440,
#  'invaluable': 441,
#  'social': 442,
#  'shortest': 443,
#  'path': 444,
#  'calculations': 445,
#  'routing': 446,
#  'protocols': 447,
#  'suitable': 448,
#  'comprehensive': 449,
#  'exploration': 450,
#  'far': 451,
#  'possible': 452,
#  'along': 453,
#  'branch': 454,
#  'backtracking': 455,
#  'utilized': 456,
#  'maze': 457,
#  'solving': 458,
#  'topological': 459,
#  'cycle': 460,
#  'detection': 461,
#  'provides': 462,
#  'insights': 463,
#  'into': 464,
#  'often': 465,
#  'chosen': 466}

# %%
for sentence in faqs.split('\n'):
  print(sentence)
# Out:
# PROGRAM OUTCOMES (POS)
# PO1: Engineering Knowledge: Apply knowledge of mathematics, science,
# engineering fundamentals and an engineering specialization to the solution complex
# engineering problems.
# PO2: Problem Analysis: Identify, formulate, research literature and analyze complex
# engineering problems reaching substantiated conclusions using first principles of
# mathematics, natural sciences and engineering sciences.
# PO3: Design/ Development of Solutions: Design solutions for complex engineering
# problems and design system components or processes that meet specified needs
# with appropriate consideration for public health and safety, cultural, societal and
# environmental considerations.
# PO4: Conduct investigations of complex problems:Use research-based knowledge
# and research methods including design of experiments, analysis and interpretation
# of data and synthesis of information to provide valid conclusions.
# PO5: Modern Tool Usage: Create, select and apply appropriate techniques,
# resources and modern engineering and IT tools including prediction and modeling to
# complex engineering activities with an understanding of the limitations.
# PO6: The Engineer and Society:Apply reasoning informed by contextual knowledge
# to assess societal, health, safety, legal and cultural issues and the consequent
# responsibilities relevant to professional engineering practice.
# PO7:  Environment and Sustainability: Understand the impact of professional
# engineering solutions in societal and environmental contexts and demonstrate
# knowledge of and need for sustainable development.
# PO8: Ethics:Apply ethical principles and commit to professional ethics and
# responsibilities and norms of engineering practice.
# PO9: Individual and Team Work:Function effectively as an individual, and as a
# member or leader in diverse teams and in multi-disciplinary settings.
# PO10: Communication: Communicate effectively on complex engineering activities
# with the engineering community and with society at large, such as being able to
# comprehend and write effective reports and design documentation, make effective
# presentations and give and receive clear instructions.
# PO11: Project Management and Finance:Demonstrate knowledge and
# understanding of engineering and management principles and apply these to one’s
# own work, as a member and leader in a team, to manage projects and in
# multidisciplinary environments.
# PO12: Life-long Learning:Recognize the need for and have the preparation and
# ability to Engage in independent and life- long learning in the broadest context of
# technological Change.
# PROGRAM SPECIFIC OUTCOMES (PSOs)
# PSO1: To collect requirements, analyze, design, implement and test software
# Systems.
# PSO2:To analyze the errors and debug them within minimal time.
# COURSE OVERVIEW:
# Advanced Data Structures Laboratory course is to improve the programming skills using
# CLanguage.This course covers implementing applications of linked lists and queues.
# Thiscourse also enables to implement search trees and graphs , dictionaries and
# hashing.Thecourse also enables to implementadvanced search tress and text processing.
# After the completion of this course student will be able to implement efficient algorithm for
# a software.
#
# COURSE OUTCOMES (COs)
#
# After the completion of the course, the student will be able to:
# CO#  Course Outcomes
# A8513.1  Implement programs using linear data structures to process data.
# A8513.2 Implement operations on non-linear data structures for handling large data.
# A8513.3 Build traversal algorithms for efficient search on nonlinear data structures.
# A8513.4 Develop algorithms for text processing applications.
# Circular Linked Lists: Circular Linked Lists are an extension of the traditional
# linked list data structure. In this variant, the last node in the list points back
# to the first node, forming a circular loop. This arrangement facilitates
# seamless traversal from any point in the list to any other point, making it
# particularly useful for scenarios where cyclic operations or continuous data
# processing is required. Circular Linked Lists find applications in tasks such as
# managing resources in a round-robin scheduling system or representing
# cyclic structures in real-world scenarios.
# Circular Queue using Linked List: A Circular Queue is a data structure that
# follows the First-In-First-Out (FIFO) principle. When implemented with a
# linked list, it allows for efficient management of a dynamic collection of
# elements. The circular arrangement eliminates the need to shift elements
# during enqueue and dequeue operations, providing a more optimized
# solution. Circular Queues are employed in scenarios where a continuous
# flow of data is desired, such as in network traffic buffering or job scheduling
# in operating systems.
# Deque using Linked List: Deque, short for double-ended queue, is a
# versatile data structure that supports insertion and deletion at both ends.
# When implemented with a linked list, it offers flexibility in managing data at
# the front and rear ends efficiently. Deques find applications in situations
# where dynamic and bidirectional data manipulation is essential, such as in
# undo mechanisms in applications or managing a sliding window of data in
# algorithms.
# Addition of Two Polynomials: Polynomial addition involves combining like
# terms from two polynomials by adding coefficients corresponding to the
# same power of the variable. This operation is fundamental in algebraic
# computations, including signal processing and cryptography. Implementing
# polynomial addition efficiently is crucial for handling large datasets and
# complex mathematical expressions.
# Multiplication of Two Polynomials: Polynomial multiplication is the process
# of multiplying each term of one polynomial by every term of the other. Thisoperation is pivotal in diverse fields, including computer graphics, error
# correction codes, and numerical simulations. Efficient implementation of
# polynomial multiplication using data structures like linked lists is essential
# for optimizing computational resources and ensuring accurate results.
# Heap Sort: Heap Sort is a comparison-based sorting algorithm that
# leverages a binary heap data structure. By creating a heap and repeatedly
# extracting the maximum element, Heap Sort achieves efficient sorting with
# a consistent time complexity. This algorithm is widely used in scenarios
# where a stable sorting solution is not critical, such as in embedded systems
# or real-time applications.
# Binary Search Trees: Binary Search Trees are hierarchical data structures
# where each node has at most two children. The left child contains values
# smaller than the node, while the right child contains values greater than the
# node. Operations on Binary Search Trees include insertion, deletion,
# searching, and traversal. These trees are employed in scenarios where
# maintaining a sorted dataset and efficient search operations are paramount,
# such as in database indexing or symbol tables in compilers.
# Breadth First Search (BFS): Breadth First Search is a graph traversal
# algorithm that explores all vertices at the current depth before moving on to
# the next level. This algorithm is invaluable in applications such as social
# network analysis, shortest path calculations, and network routing protocols.
# BFS efficiently covers the breadth of a graph, making it suitable for scenarios
# where a comprehensive exploration of the structure is required.
# Depth First Search (DFS): Depth First Search is a graph traversal algorithm
# that explores as far as possible along each branch before backtracking. DFS
# is utilized in diverse applications, including maze solving, topological sorting,
# and cycle detection in graphs. This algorithm provides insights into the
# structure of a graph and is often chosen based on specific problem
# requirements.

# %%
for senetence in faqs.split('\n'):
  print(tokenizer.texts_to_sequences([senetence])[0])
# Out:
# [87, 48, 168]
# [169, 9, 27, 35, 27, 4, 88, 170]
# [9, 171, 1, 49, 9, 172, 6, 2, 58, 19]
# [9, 50]
# [173, 89, 59, 174, 175, 60, 176, 1, 61, 19]
# [9, 50, 177, 178, 90, 28, 14, 62, 4]
# [88, 179, 91, 1, 9, 91]
# [180, 29, 92, 4, 63, 29, 63, 10, 19, 9]
# [50, 1, 29, 93, 181, 15, 182, 30, 183, 184, 185]
# [20, 94, 186, 10, 187, 95, 1, 96, 97, 64, 1]
# [98, 188]
# [189, 190, 191, 4, 19, 50, 192, 60, 65, 27]
# [1, 60, 193, 36, 29, 4, 194, 59, 1, 195]
# [4, 8, 1, 196, 4, 197, 6, 198, 199, 90]
# [200, 99, 201, 202, 203, 204, 1, 35, 94, 205]
# [66, 1, 99, 9, 1, 37, 206, 36, 207, 1, 208, 6]
# [19, 9, 100, 20, 49, 101, 4, 2, 209]
# [210, 2, 211, 1, 102, 35, 212, 213, 51, 214, 27]
# [6, 215, 64, 95, 96, 216, 1, 97, 217, 1, 2, 218]
# [103, 219, 6, 67, 9, 104]
# [220, 221, 1, 222, 223, 2, 224, 4, 67]
# [9, 63, 3, 64, 1, 98, 225, 1, 105]
# [27, 4, 1, 68, 10, 226, 92]
# [227, 106, 35, 228, 62, 1, 229, 6, 67, 106, 1]
# [103, 1, 230, 4, 9, 104]
# [231, 107, 1, 108, 109, 232, 110, 11, 49, 107, 1, 11, 5]
# [111, 15, 112, 3, 69, 233, 1, 3, 234, 235, 236]
# [237, 238, 239, 110, 31, 19, 9, 100]
# [20, 2, 9, 240, 1, 20, 102, 38, 70, 21, 11, 241, 71, 6]
# [242, 1, 243, 113, 244, 1, 29, 245, 246, 113]
# [247, 1, 248, 1, 249, 250, 251]
# [252, 253, 72, 1, 254, 105, 27, 1]
# [101, 4, 9, 1, 72, 62, 1, 35, 114, 6, 255]
# [256, 109, 11, 5, 111, 1, 112, 3, 5, 108, 6, 257, 258, 1, 3]
# [259, 260]
# [261, 115, 116, 117, 262, 2, 68, 10, 1, 263, 2, 264, 1]
# [265, 6, 266, 3, 267, 1, 115, 116, 117, 3, 2, 268, 269, 4]
# [270, 271]
# [87, 118, 48, 272]
# [273, 6, 274, 119, 61, 29, 39, 1, 275, 120]
# [73]
# [276, 6, 61, 2, 277, 1, 278, 279, 280, 281, 74]
# [22, 282]
# [283, 8, 23, 284, 22, 7, 6, 285, 2, 286, 287, 28]
# [288, 16, 22, 121, 122, 17, 4, 13, 40, 1, 123]
# [289, 124, 125, 6, 39, 12, 41, 1, 126, 290, 1]
# [291, 292, 124, 125, 6, 293, 12, 294, 1, 127, 52]
# [128, 2, 129, 4, 16, 22, 130, 131, 132, 71, 6, 39, 32, 24, 10]
# [5, 120]
# []
# [22, 48, 295]
# []
# [128, 2, 129, 4, 2, 22, 2, 130, 131, 132, 71, 6]
# [296, 22, 48]
# [53, 297, 39, 298, 28, 133, 8, 23, 6, 134, 8]
# [53, 299, 39, 42, 31, 300, 133, 8, 23, 10, 135, 70, 8]
# [53, 301, 302, 43, 75, 10, 32, 12, 31, 303, 8, 23]
# [53, 304, 305, 75, 10, 127, 52, 17]
# [18, 13, 40, 18, 13, 40, 44, 49, 306, 4, 2, 307]
# [13, 25, 8, 33, 3, 16, 308, 2, 309, 45, 3, 2, 25, 310, 311]
# [6, 2, 14, 45, 312, 5, 18, 313, 16, 136, 314]
# [315, 43, 137, 138, 139, 3, 2, 25, 6, 138, 140, 139, 141, 37]
# [316, 317, 10, 34, 26, 142, 42, 15, 143, 8]
# [52, 7, 144, 18, 13, 40, 145, 17, 3, 318, 21, 11]
# [76, 66, 3, 5, 319, 320, 146, 93, 15, 321]
# [142, 23, 3, 147, 322, 34]
# [18, 77, 28, 13, 25, 5, 18, 77, 7, 5, 8, 33, 30]
# [323, 2, 14, 3, 14, 324, 325, 326, 148, 149, 20, 5]
# [13, 25, 37, 327, 10, 32, 72, 4, 5, 150, 328, 4]
# [151, 2, 18, 136, 329, 2, 68, 6, 330, 151]
# [331, 332, 1, 333, 42, 334, 5, 335, 336]
# [58, 18, 123, 44, 152, 3, 34, 26, 5, 143]
# [337, 4, 8, 7, 338, 21, 11, 3, 78, 339, 340, 15, 341, 146]
# [3, 342, 73]
# [153, 28, 13, 25, 153, 343, 10, 344, 345, 77, 7, 5]
# [346, 8, 33, 30, 347, 154, 1, 155, 38, 348, 156]
# [148, 149, 20, 5, 13, 25, 37, 349, 350, 3, 76, 8, 38]
# [2, 351, 1, 352, 156, 79, 353, 145, 17, 3, 354]
# [26, 150, 1, 355, 8, 356, 7, 157, 21, 11, 3]
# [357, 358, 3, 17, 15, 76, 5, 359, 360, 4, 8, 3]
# [75]
# [80, 4, 54, 81, 46, 80, 361, 362, 158]
# [363, 137, 54, 81, 51, 364, 365, 366, 6, 2]
# [367, 368, 4, 2, 369, 16, 370, 7, 371, 3, 372]
# [373, 36, 374, 52, 1, 375, 122]
# [46, 80, 79, 7, 376, 10, 135, 70, 377, 1]
# [19, 378, 379]
# [82, 4, 54, 81, 46, 82, 7, 2, 134]
# [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140, 383, 7, 384, 3, 69, 385, 36, 386, 387, 388]
# [389, 390, 1, 391, 392, 32, 393, 4]
# [46, 82, 28, 8, 23, 158, 13, 40, 7, 157]
# [10, 394, 395, 66, 1, 396, 397, 398]
# [47, 84, 47, 84, 7, 5, 399, 65, 55, 24, 30]
# [400, 5, 56, 47, 8, 33, 51, 401, 5, 47, 1, 402]
# [403, 2, 404, 405, 47, 84, 406, 32, 55, 20]
# [5, 407, 74, 408, 16, 24, 7, 409, 410, 3, 34]
# [26, 5, 411, 55, 58, 7, 412, 413, 21, 11, 3, 414, 73]
# [15, 147, 74, 17]
# [56, 12, 41, 56, 12, 41, 44, 415, 8, 23]
# [26, 83, 45, 416, 38, 417, 54, 418, 2, 419, 160, 161, 162]
# [420, 163, 2, 45, 421, 2, 422, 160, 161, 162, 423, 163, 2]
# [45, 42, 31, 56, 12, 41, 424, 154, 155]
# [425, 1, 43, 114, 41, 44, 152, 3, 34, 26]
# [426, 5, 427, 428, 1, 32, 12, 42, 44, 429]
# [21, 11, 3, 430, 431, 15, 432, 433, 3, 434]
# [85, 14, 12, 164, 85, 14, 12, 7, 5, 57, 43]
# [24, 30, 165, 435, 436, 38, 2, 437, 86, 166, 438, 31, 6]
# [2, 439, 440, 16, 24, 7, 441, 3, 17, 21, 11, 442]
# [78, 59, 443, 444, 445, 1, 78, 446, 447]
# [164, 79, 121, 2, 85, 4, 5, 57, 141, 37, 448, 10, 34]
# [26, 5, 449, 450, 4, 2, 33, 7, 144]
# [86, 14, 12, 167, 86, 14, 12, 7, 5, 57, 43, 24]
# [30, 165, 11, 451, 11, 452, 453, 83, 454, 166, 455, 167]
# [7, 456, 3, 69, 17, 36, 457, 458, 459, 55]
# [1, 460, 461, 3, 126, 16, 24, 462, 463, 464, 2]
# [33, 4, 5, 57, 1, 7, 465, 466, 65, 31, 118, 89]
# [119]
# []
# []

# %%
input_sequ=[]
for sentence in faqs.split('\n'):
  tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]
  print(tokenized_sentence)
  for i in range(1,len(tokenized_sentence)):
    input_sequ.append(tokenized_sentence[:i+1])
# Out:
# [87, 48, 168]
# [169, 9, 27, 35, 27, 4, 88, 170]
# [9, 171, 1, 49, 9, 172, 6, 2, 58, 19]
# [9, 50]
# [173, 89, 59, 174, 175, 60, 176, 1, 61, 19]
# [9, 50, 177, 178, 90, 28, 14, 62, 4]
# [88, 179, 91, 1, 9, 91]
# [180, 29, 92, 4, 63, 29, 63, 10, 19, 9]
# [50, 1, 29, 93, 181, 15, 182, 30, 183, 184, 185]
# [20, 94, 186, 10, 187, 95, 1, 96, 97, 64, 1]
# [98, 188]
# [189, 190, 191, 4, 19, 50, 192, 60, 65, 27]
# [1, 60, 193, 36, 29, 4, 194, 59, 1, 195]
# [4, 8, 1, 196, 4, 197, 6, 198, 199, 90]
# [200, 99, 201, 202, 203, 204, 1, 35, 94, 205]
# [66, 1, 99, 9, 1, 37, 206, 36, 207, 1, 208, 6]
# [19, 9, 100, 20, 49, 101, 4, 2, 209]
# [210, 2, 211, 1, 102, 35, 212, 213, 51, 214, 27]
# [6, 215, 64, 95, 96, 216, 1, 97, 217, 1, 2, 218]
# [103, 219, 6, 67, 9, 104]
# [220, 221, 1, 222, 223, 2, 224, 4, 67]
# [9, 63, 3, 64, 1, 98, 225, 1, 105]
# [27, 4, 1, 68, 10, 226, 92]
# [227, 106, 35, 228, 62, 1, 229, 6, 67, 106, 1]
# [103, 1, 230, 4, 9, 104]
# [231, 107, 1, 108, 109, 232, 110, 11, 49, 107, 1, 11, 5]
# [111, 15, 112, 3, 69, 233, 1, 3, 234, 235, 236]
# [237, 238, 239, 110, 31, 19, 9, 100]
# [20, 2, 9, 240, 1, 20, 102, 38, 70, 21, 11, 241, 71, 6]
# [242, 1, 243, 113, 244, 1, 29, 245, 246, 113]
# [247, 1, 248, 1, 249, 250, 251]
# [252, 253, 72, 1, 254, 105, 27, 1]
# [101, 4, 9, 1, 72, 62, 1, 35, 114, 6, 255]
# [256, 109, 11, 5, 111, 1, 112, 3, 5, 108, 6, 257, 258, 1, 3]
# [259, 260]
# [261, 115, 116, 117, 262, 2, 68, 10, 1, 263, 2, 264, 1]
# [265, 6, 266, 3, 267, 1, 115, 116, 117, 3, 2, 268, 269, 4]
# [270, 271]
# [87, 118, 48, 272]
# [273, 6, 274, 119, 61, 29, 39, 1, 275, 120]
# [73]
# [276, 6, 61, 2, 277, 1, 278, 279, 280, 281, 74]
# [22, 282]
# [283, 8, 23, 284, 22, 7, 6, 285, 2, 286, 287, 28]
# [288, 16, 22, 121, 122, 17, 4, 13, 40, 1, 123]
# [289, 124, 125, 6, 39, 12, 41, 1, 126, 290, 1]
# [291, 292, 124, 125, 6, 293, 12, 294, 1, 127, 52]
# [128, 2, 129, 4, 16, 22, 130, 131, 132, 71, 6, 39, 32, 24, 10]
# [5, 120]
# []
# [22, 48, 295]
# []
# [128, 2, 129, 4, 2, 22, 2, 130, 131, 132, 71, 6]
# [296, 22, 48]
# [53, 297, 39, 298, 28, 133, 8, 23, 6, 134, 8]
# [53, 299, 39, 42, 31, 300, 133, 8, 23, 10, 135, 70, 8]
# [53, 301, 302, 43, 75, 10, 32, 12, 31, 303, 8, 23]
# [53, 304, 305, 75, 10, 127, 52, 17]
# [18, 13, 40, 18, 13, 40, 44, 49, 306, 4, 2, 307]
# [13, 25, 8, 33, 3, 16, 308, 2, 309, 45, 3, 2, 25, 310, 311]
# [6, 2, 14, 45, 312, 5, 18, 313, 16, 136, 314]
# [315, 43, 137, 138, 139, 3, 2, 25, 6, 138, 140, 139, 141, 37]
# [316, 317, 10, 34, 26, 142, 42, 15, 143, 8]
# [52, 7, 144, 18, 13, 40, 145, 17, 3, 318, 21, 11]
# [76, 66, 3, 5, 319, 320, 146, 93, 15, 321]
# [142, 23, 3, 147, 322, 34]
# [18, 77, 28, 13, 25, 5, 18, 77, 7, 5, 8, 33, 30]
# [323, 2, 14, 3, 14, 324, 325, 326, 148, 149, 20, 5]
# [13, 25, 37, 327, 10, 32, 72, 4, 5, 150, 328, 4]
# [151, 2, 18, 136, 329, 2, 68, 6, 330, 151]
# [331, 332, 1, 333, 42, 334, 5, 335, 336]
# [58, 18, 123, 44, 152, 3, 34, 26, 5, 143]
# [337, 4, 8, 7, 338, 21, 11, 3, 78, 339, 340, 15, 341, 146]
# [3, 342, 73]
# [153, 28, 13, 25, 153, 343, 10, 344, 345, 77, 7, 5]
# [346, 8, 33, 30, 347, 154, 1, 155, 38, 348, 156]
# [148, 149, 20, 5, 13, 25, 37, 349, 350, 3, 76, 8, 38]
# [2, 351, 1, 352, 156, 79, 353, 145, 17, 3, 354]
# [26, 150, 1, 355, 8, 356, 7, 157, 21, 11, 3]
# [357, 358, 3, 17, 15, 76, 5, 359, 360, 4, 8, 3]
# [75]
# [80, 4, 54, 81, 46, 80, 361, 362, 158]
# [363, 137, 54, 81, 51, 364, 365, 366, 6, 2]
# [367, 368, 4, 2, 369, 16, 370, 7, 371, 3, 372]
# [373, 36, 374, 52, 1, 375, 122]
# [46, 80, 79, 7, 376, 10, 135, 70, 377, 1]
# [19, 378, 379]
# [82, 4, 54, 81, 46, 82, 7, 2, 134]
# [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140, 383, 7, 384, 3, 69, 385, 36, 386, 387, 388]
# [389, 390, 1, 391, 392, 32, 393, 4]
# [46, 82, 28, 8, 23, 158, 13, 40, 7, 157]
# [10, 394, 395, 66, 1, 396, 397, 398]
# [47, 84, 47, 84, 7, 5, 399, 65, 55, 24, 30]
# [400, 5, 56, 47, 8, 33, 51, 401, 5, 47, 1, 402]
# [403, 2, 404, 405, 47, 84, 406, 32, 55, 20]
# [5, 407, 74, 408, 16, 24, 7, 409, 410, 3, 34]
# [26, 5, 411, 55, 58, 7, 412, 413, 21, 11, 3, 414, 73]
# [15, 147, 74, 17]
# [56, 12, 41, 56, 12, 41, 44, 415, 8, 23]
# [26, 83, 45, 416, 38, 417, 54, 418, 2, 419, 160, 161, 162]
# [420, 163, 2, 45, 421, 2, 422, 160, 161, 162, 423, 163, 2]
# [45, 42, 31, 56, 12, 41, 424, 154, 155]
# [425, 1, 43, 114, 41, 44, 152, 3, 34, 26]
# [426, 5, 427, 428, 1, 32, 12, 42, 44, 429]
# [21, 11, 3, 430, 431, 15, 432, 433, 3, 434]
# [85, 14, 12, 164, 85, 14, 12, 7, 5, 57, 43]
# [24, 30, 165, 435, 436, 38, 2, 437, 86, 166, 438, 31, 6]
# [2, 439, 440, 16, 24, 7, 441, 3, 17, 21, 11, 442]
# [78, 59, 443, 444, 445, 1, 78, 446, 447]
# [164, 79, 121, 2, 85, 4, 5, 57, 141, 37, 448, 10, 34]
# [26, 5, 449, 450, 4, 2, 33, 7, 144]
# [86, 14, 12, 167, 86, 14, 12, 7, 5, 57, 43, 24]
# [30, 165, 11, 451, 11, 452, 453, 83, 454, 166, 455, 167]
# [7, 456, 3, 69, 17, 36, 457, 458, 459, 55]
# [1, 460, 461, 3, 126, 16, 24, 462, 463, 464, 2]
# [33, 4, 5, 57, 1, 7, 465, 466, 65, 31, 118, 89]
# [119]
# []
# []

# %%
input_sequ
# Out:
# [[87, 48],
#  [87, 48, 168],
#  [169, 9],
#  [169, 9, 27],
#  [169, 9, 27, 35],
#  [169, 9, 27, 35, 27],
#  [169, 9, 27, 35, 27, 4],
#  [169, 9, 27, 35, 27, 4, 88],
#  [169, 9, 27, 35, 27, 4, 88, 170],
#  [9, 171],
#  [9, 171, 1],
#  [9, 171, 1, 49],
#  [9, 171, 1, 49, 9],
#  [9, 171, 1, 49, 9, 172],
#  [9, 171, 1, 49, 9, 172, 6],
#  [9, 171, 1, 49, 9, 172, 6, 2],
#  [9, 171, 1, 49, 9, 172, 6, 2, 58],
#  [9, 171, 1, 49, 9, 172, 6, 2, 58, 19],
#  [9, 50],
#  [173, 89],
#  [173, 89, 59],
#  [173, 89, 59, 174],
#  [173, 89, 59, 174, 175],
#  [173, 89, 59, 174, 175, 60],
#  [173, 89, 59, 174, 175, 60, 176],
#  [173, 89, 59, 174, 175, 60, 176, 1],
#  [173, 89, 59, 174, 175, 60, 176, 1, 61],
#  [173, 89, 59, 174, 175, 60, 176, 1, 61, 19],
#  [9, 50],
#  [9, 50, 177],
#  [9, 50, 177, 178],
#  [9, 50, 177, 178, 90],
#  [9, 50, 177, 178, 90, 28],
#  [9, 50, 177, 178, 90, 28, 14],
#  [9, 50, 177, 178, 90, 28, 14, 62],
#  [9, 50, 177, 178, 90, 28, 14, 62, 4],
#  [88, 179],
#  [88, 179, 91],
#  [88, 179, 91, 1],
#  [88, 179, 91, 1, 9],
#  [88, 179, 91, 1, 9, 91],
#  [180, 29],
#  [180, 29, 92],
#  [180, 29, 92, 4],
#  [180, 29, 92, 4, 63],
#  [180, 29, 92, 4, 63, 29],
#  [180, 29, 92, 4, 63, 29, 63],
#  [180, 29, 92, 4, 63, 29, 63, 10],
#  [180, 29, 92, 4, 63, 29, 63, 10, 19],
#  [180, 29, 92, 4, 63, 29, 63, 10, 19, 9],
#  [50, 1],
#  [50, 1, 29],
#  [50, 1, 29, 93],
#  [50, 1, 29, 93, 181],
#  [50, 1, 29, 93, 181, 15],
#  [50, 1, 29, 93, 181, 15, 182],
#  [50, 1, 29, 93, 181, 15, 182, 30],
#  [50, 1, 29, 93, 181, 15, 182, 30, 183],
#  [50, 1, 29, 93, 181, 15, 182, 30, 183, 184],
#  [50, 1, 29, 93, 181, 15, 182, 30, 183, 184, 185],
#  [20, 94],
#  [20, 94, 186],
#  [20, 94, 186, 10],
#  [20, 94, 186, 10, 187],
#  [20, 94, 186, 10, 187, 95],
#  [20, 94, 186, 10, 187, 95, 1],
#  [20, 94, 186, 10, 187, 95, 1, 96],
#  [20, 94, 186, 10, 187, 95, 1, 96, 97],
#  [20, 94, 186, 10, 187, 95, 1, 96, 97, 64],
#  [20, 94, 186, 10, 187, 95, 1, 96, 97, 64, 1],
#  [98, 188],
#  [189, 190],
#  [189, 190, 191],
#  [189, 190, 191, 4],
#  [189, 190, 191, 4, 19],
#  [189, 190, 191, 4, 19, 50],
#  [189, 190, 191, 4, 19, 50, 192],
#  [189, 190, 191, 4, 19, 50, 192, 60],
#  [189, 190, 191, 4, 19, 50, 192, 60, 65],
#  [189, 190, 191, 4, 19, 50, 192, 60, 65, 27],
#  [1, 60],
#  [1, 60, 193],
#  [1, 60, 193, 36],
#  [1, 60, 193, 36, 29],
#  [1, 60, 193, 36, 29, 4],
#  [1, 60, 193, 36, 29, 4, 194],
#  [1, 60, 193, 36, 29, 4, 194, 59],
#  [1, 60, 193, 36, 29, 4, 194, 59, 1],
#  [1, 60, 193, 36, 29, 4, 194, 59, 1, 195],
#  [4, 8],
#  [4, 8, 1],
#  [4, 8, 1, 196],
#  [4, 8, 1, 196, 4],
#  [4, 8, 1, 196, 4, 197],
#  [4, 8, 1, 196, 4, 197, 6],
#  [4, 8, 1, 196, 4, 197, 6, 198],
#  [4, 8, 1, 196, 4, 197, 6, 198, 199],
#  [4, 8, 1, 196, 4, 197, 6, 198, 199, 90],
#  [200, 99],
#  [200, 99, 201],
#  [200, 99, 201, 202],
#  [200, 99, 201, 202, 203],
#  [200, 99, 201, 202, 203, 204],
#  [200, 99, 201, 202, 203, 204, 1],
#  [200, 99, 201, 202, 203, 204, 1, 35],
#  [200, 99, 201, 202, 203, 204, 1, 35, 94],
#  [200, 99, 201, 202, 203, 204, 1, 35, 94, 205],
#  [66, 1],
#  [66, 1, 99],
#  [66, 1, 99, 9],
#  [66, 1, 99, 9, 1],
#  [66, 1, 99, 9, 1, 37],
#  [66, 1, 99, 9, 1, 37, 206],
#  [66, 1, 99, 9, 1, 37, 206, 36],
#  [66, 1, 99, 9, 1, 37, 206, 36, 207],
#  [66, 1, 99, 9, 1, 37, 206, 36, 207, 1],
#  [66, 1, 99, 9, 1, 37, 206, 36, 207, 1, 208],
#  [66, 1, 99, 9, 1, 37, 206, 36, 207, 1, 208, 6],
#  [19, 9],
#  [19, 9, 100],
#  [19, 9, 100, 20],
#  [19, 9, 100, 20, 49],
#  [19, 9, 100, 20, 49, 101],
#  [19, 9, 100, 20, 49, 101, 4],
#  [19, 9, 100, 20, 49, 101, 4, 2],
#  [19, 9, 100, 20, 49, 101, 4, 2, 209],
#  [210, 2],
#  [210, 2, 211],
#  [210, 2, 211, 1],
#  [210, 2, 211, 1, 102],
#  [210, 2, 211, 1, 102, 35],
#  [210, 2, 211, 1, 102, 35, 212],
#  [210, 2, 211, 1, 102, 35, 212, 213],
#  [210, 2, 211, 1, 102, 35, 212, 213, 51],
#  [210, 2, 211, 1, 102, 35, 212, 213, 51, 214],
#  [210, 2, 211, 1, 102, 35, 212, 213, 51, 214, 27],
#  [6, 215],
#  [6, 215, 64],
#  [6, 215, 64, 95],
#  [6, 215, 64, 95, 96],
#  [6, 215, 64, 95, 96, 216],
#  [6, 215, 64, 95, 96, 216, 1],
#  [6, 215, 64, 95, 96, 216, 1, 97],
#  [6, 215, 64, 95, 96, 216, 1, 97, 217],
#  [6, 215, 64, 95, 96, 216, 1, 97, 217, 1],
#  [6, 215, 64, 95, 96, 216, 1, 97, 217, 1, 2],
#  [6, 215, 64, 95, 96, 216, 1, 97, 217, 1, 2, 218],
#  [103, 219],
#  [103, 219, 6],
#  [103, 219, 6, 67],
#  [103, 219, 6, 67, 9],
#  [103, 219, 6, 67, 9, 104],
#  [220, 221],
#  [220, 221, 1],
#  [220, 221, 1, 222],
#  [220, 221, 1, 222, 223],
#  [220, 221, 1, 222, 223, 2],
#  [220, 221, 1, 222, 223, 2, 224],
#  [220, 221, 1, 222, 223, 2, 224, 4],
#  [220, 221, 1, 222, 223, 2, 224, 4, 67],
#  [9, 63],
#  [9, 63, 3],
#  [9, 63, 3, 64],
#  [9, 63, 3, 64, 1],
#  [9, 63, 3, 64, 1, 98],
#  [9, 63, 3, 64, 1, 98, 225],
#  [9, 63, 3, 64, 1, 98, 225, 1],
#  [9, 63, 3, 64, 1, 98, 225, 1, 105],
#  [27, 4],
#  [27, 4, 1],
#  [27, 4, 1, 68],
#  [27, 4, 1, 68, 10],
#  [27, 4, 1, 68, 10, 226],
#  [27, 4, 1, 68, 10, 226, 92],
#  [227, 106],
#  [227, 106, 35],
#  [227, 106, 35, 228],
#  [227, 106, 35, 228, 62],
#  [227, 106, 35, 228, 62, 1],
#  [227, 106, 35, 228, 62, 1, 229],
#  [227, 106, 35, 228, 62, 1, 229, 6],
#  [227, 106, 35, 228, 62, 1, 229, 6, 67],
#  [227, 106, 35, 228, 62, 1, 229, 6, 67, 106],
#  [227, 106, 35, 228, 62, 1, 229, 6, 67, 106, 1],
#  [103, 1],
#  [103, 1, 230],
#  [103, 1, 230, 4],
#  [103, 1, 230, 4, 9],
#  [103, 1, 230, 4, 9, 104],
#  [231, 107],
#  [231, 107, 1],
#  [231, 107, 1, 108],
#  [231, 107, 1, 108, 109],
#  [231, 107, 1, 108, 109, 232],
#  [231, 107, 1, 108, 109, 232, 110],
#  [231, 107, 1, 108, 109, 232, 110, 11],
#  [231, 107, 1, 108, 109, 232, 110, 11, 49],
#  [231, 107, 1, 108, 109, 232, 110, 11, 49, 107],
#  [231, 107, 1, 108, 109, 232, 110, 11, 49, 107, 1],
#  [231, 107, 1, 108, 109, 232, 110, 11, 49, 107, 1, 11],
#  [231, 107, 1, 108, 109, 232, 110, 11, 49, 107, 1, 11, 5],
#  [111, 15],
#  [111, 15, 112],
#  [111, 15, 112, 3],
#  [111, 15, 112, 3, 69],
#  [111, 15, 112, 3, 69, 233],
#  [111, 15, 112, 3, 69, 233, 1],
#  [111, 15, 112, 3, 69, 233, 1, 3],
#  [111, 15, 112, 3, 69, 233, 1, 3, 234],
#  [111, 15, 112, 3, 69, 233, 1, 3, 234, 235],
#  [111, 15, 112, 3, 69, 233, 1, 3, 234, 235, 236],
#  [237, 238],
#  [237, 238, 239],
#  [237, 238, 239, 110],
#  [237, 238, 239, 110, 31],
#  [237, 238, 239, 110, 31, 19],
#  [237, 238, 239, 110, 31, 19, 9],
#  [237, 238, 239, 110, 31, 19, 9, 100],
#  [20, 2],
#  [20, 2, 9],
#  [20, 2, 9, 240],
#  [20, 2, 9, 240, 1],
#  [20, 2, 9, 240, 1, 20],
#  [20, 2, 9, 240, 1, 20, 102],
#  [20, 2, 9, 240, 1, 20, 102, 38],
#  [20, 2, 9, 240, 1, 20, 102, 38, 70],
#  [20, 2, 9, 240, 1, 20, 102, 38, 70, 21],
#  [20, 2, 9, 240, 1, 20, 102, 38, 70, 21, 11],
#  [20, 2, 9, 240, 1, 20, 102, 38, 70, 21, 11, 241],
#  [20, 2, 9, 240, 1, 20, 102, 38, 70, 21, 11, 241, 71],
#  [20, 2, 9, 240, 1, 20, 102, 38, 70, 21, 11, 241, 71, 6],
#  [242, 1],
#  [242, 1, 243],
#  [242, 1, 243, 113],
#  [242, 1, 243, 113, 244],
#  [242, 1, 243, 113, 244, 1],
#  [242, 1, 243, 113, 244, 1, 29],
#  [242, 1, 243, 113, 244, 1, 29, 245],
#  [242, 1, 243, 113, 244, 1, 29, 245, 246],
#  [242, 1, 243, 113, 244, 1, 29, 245, 246, 113],
#  [247, 1],
#  [247, 1, 248],
#  [247, 1, 248, 1],
#  [247, 1, 248, 1, 249],
#  [247, 1, 248, 1, 249, 250],
#  [247, 1, 248, 1, 249, 250, 251],
#  [252, 253],
#  [252, 253, 72],
#  [252, 253, 72, 1],
#  [252, 253, 72, 1, 254],
#  [252, 253, 72, 1, 254, 105],
#  [252, 253, 72, 1, 254, 105, 27],
#  [252, 253, 72, 1, 254, 105, 27, 1],
#  [101, 4],
#  [101, 4, 9],
#  [101, 4, 9, 1],
#  [101, 4, 9, 1, 72],
#  [101, 4, 9, 1, 72, 62],
#  [101, 4, 9, 1, 72, 62, 1],
#  [101, 4, 9, 1, 72, 62, 1, 35],
#  [101, 4, 9, 1, 72, 62, 1, 35, 114],
#  [101, 4, 9, 1, 72, 62, 1, 35, 114, 6],
#  [101, 4, 9, 1, 72, 62, 1, 35, 114, 6, 255],
#  [256, 109],
#  [256, 109, 11],
#  [256, 109, 11, 5],
#  [256, 109, 11, 5, 111],
#  [256, 109, 11, 5, 111, 1],
#  [256, 109, 11, 5, 111, 1, 112],
#  [256, 109, 11, 5, 111, 1, 112, 3],
#  [256, 109, 11, 5, 111, 1, 112, 3, 5],
#  [256, 109, 11, 5, 111, 1, 112, 3, 5, 108],
#  [256, 109, 11, 5, 111, 1, 112, 3, 5, 108, 6],
#  [256, 109, 11, 5, 111, 1, 112, 3, 5, 108, 6, 257],
#  [256, 109, 11, 5, 111, 1, 112, 3, 5, 108, 6, 257, 258],
#  [256, 109, 11, 5, 111, 1, 112, 3, 5, 108, 6, 257, 258, 1],
#  [256, 109, 11, 5, 111, 1, 112, 3, 5, 108, 6, 257, 258, 1, 3],
#  [259, 260],
#  [261, 115],
#  [261, 115, 116],
#  [261, 115, 116, 117],
#  [261, 115, 116, 117, 262],
#  [261, 115, 116, 117, 262, 2],
#  [261, 115, 116, 117, 262, 2, 68],
#  [261, 115, 116, 117, 262, 2, 68, 10],
#  [261, 115, 116, 117, 262, 2, 68, 10, 1],
#  [261, 115, 116, 117, 262, 2, 68, 10, 1, 263],
#  [261, 115, 116, 117, 262, 2, 68, 10, 1, 263, 2],
#  [261, 115, 116, 117, 262, 2, 68, 10, 1, 263, 2, 264],
#  [261, 115, 116, 117, 262, 2, 68, 10, 1, 263, 2, 264, 1],
#  [265, 6],
#  [265, 6, 266],
#  [265, 6, 266, 3],
#  [265, 6, 266, 3, 267],
#  [265, 6, 266, 3, 267, 1],
#  [265, 6, 266, 3, 267, 1, 115],
#  [265, 6, 266, 3, 267, 1, 115, 116],
#  [265, 6, 266, 3, 267, 1, 115, 116, 117],
#  [265, 6, 266, 3, 267, 1, 115, 116, 117, 3],
#  [265, 6, 266, 3, 267, 1, 115, 116, 117, 3, 2],
#  [265, 6, 266, 3, 267, 1, 115, 116, 117, 3, 2, 268],
#  [265, 6, 266, 3, 267, 1, 115, 116, 117, 3, 2, 268, 269],
#  [265, 6, 266, 3, 267, 1, 115, 116, 117, 3, 2, 268, 269, 4],
#  [270, 271],
#  [87, 118],
#  [87, 118, 48],
#  [87, 118, 48, 272],
#  [273, 6],
#  [273, 6, 274],
#  [273, 6, 274, 119],
#  [273, 6, 274, 119, 61],
#  [273, 6, 274, 119, 61, 29],
#  [273, 6, 274, 119, 61, 29, 39],
#  [273, 6, 274, 119, 61, 29, 39, 1],
#  [273, 6, 274, 119, 61, 29, 39, 1, 275],
#  [273, 6, 274, 119, 61, 29, 39, 1, 275, 120],
#  [276, 6],
#  [276, 6, 61],
#  [276, 6, 61, 2],
#  [276, 6, 61, 2, 277],
#  [276, 6, 61, 2, 277, 1],
#  [276, 6, 61, 2, 277, 1, 278],
#  [276, 6, 61, 2, 277, 1, 278, 279],
#  [276, 6, 61, 2, 277, 1, 278, 279, 280],
#  [276, 6, 61, 2, 277, 1, 278, 279, 280, 281],
#  [276, 6, 61, 2, 277, 1, 278, 279, 280, 281, 74],
#  [22, 282],
#  [283, 8],
#  [283, 8, 23],
#  [283, 8, 23, 284],
#  [283, 8, 23, 284, 22],
#  [283, 8, 23, 284, 22, 7],
#  [283, 8, 23, 284, 22, 7, 6],
#  [283, 8, 23, 284, 22, 7, 6, 285],
#  [283, 8, 23, 284, 22, 7, 6, 285, 2],
#  [283, 8, 23, 284, 22, 7, 6, 285, 2, 286],
#  [283, 8, 23, 284, 22, 7, 6, 285, 2, 286, 287],
#  [283, 8, 23, 284, 22, 7, 6, 285, 2, 286, 287, 28],
#  [288, 16],
#  [288, 16, 22],
#  [288, 16, 22, 121],
#  [288, 16, 22, 121, 122],
#  [288, 16, 22, 121, 122, 17],
#  [288, 16, 22, 121, 122, 17, 4],
#  [288, 16, 22, 121, 122, 17, 4, 13],
#  [288, 16, 22, 121, 122, 17, 4, 13, 40],
#  [288, 16, 22, 121, 122, 17, 4, 13, 40, 1],
#  [288, 16, 22, 121, 122, 17, 4, 13, 40, 1, 123],
#  [289, 124],
#  [289, 124, 125],
#  [289, 124, 125, 6],
#  [289, 124, 125, 6, 39],
#  [289, 124, 125, 6, 39, 12],
#  [289, 124, 125, 6, 39, 12, 41],
#  [289, 124, 125, 6, 39, 12, 41, 1],
#  [289, 124, 125, 6, 39, 12, 41, 1, 126],
#  [289, 124, 125, 6, 39, 12, 41, 1, 126, 290],
#  [289, 124, 125, 6, 39, 12, 41, 1, 126, 290, 1],
#  [291, 292],
#  [291, 292, 124],
#  [291, 292, 124, 125],
#  [291, 292, 124, 125, 6],
#  [291, 292, 124, 125, 6, 293],
#  [291, 292, 124, 125, 6, 293, 12],
#  [291, 292, 124, 125, 6, 293, 12, 294],
#  [291, 292, 124, 125, 6, 293, 12, 294, 1],
#  [291, 292, 124, 125, 6, 293, 12, 294, 1, 127],
#  [291, 292, 124, 125, 6, 293, 12, 294, 1, 127, 52],
#  [128, 2],
#  [128, 2, 129],
#  [128, 2, 129, 4],
#  [128, 2, 129, 4, 16],
#  [128, 2, 129, 4, 16, 22],
#  [128, 2, 129, 4, 16, 22, 130],
#  [128, 2, 129, 4, 16, 22, 130, 131],
#  [128, 2, 129, 4, 16, 22, 130, 131, 132],
#  [128, 2, 129, 4, 16, 22, 130, 131, 132, 71],
#  [128, 2, 129, 4, 16, 22, 130, 131, 132, 71, 6],
#  [128, 2, 129, 4, 16, 22, 130, 131, 132, 71, 6, 39],
#  [128, 2, 129, 4, 16, 22, 130, 131, 132, 71, 6, 39, 32],
#  [128, 2, 129, 4, 16, 22, 130, 131, 132, 71, 6, 39, 32, 24],
#  [128, 2, 129, 4, 16, 22, 130, 131, 132, 71, 6, 39, 32, 24, 10],
#  [5, 120],
#  [22, 48],
#  [22, 48, 295],
#  [128, 2],
#  [128, 2, 129],
#  [128, 2, 129, 4],
#  [128, 2, 129, 4, 2],
#  [128, 2, 129, 4, 2, 22],
#  [128, 2, 129, 4, 2, 22, 2],
#  [128, 2, 129, 4, 2, 22, 2, 130],
#  [128, 2, 129, 4, 2, 22, 2, 130, 131],
#  [128, 2, 129, 4, 2, 22, 2, 130, 131, 132],
#  [128, 2, 129, 4, 2, 22, 2, 130, 131, 132, 71],
#  [128, 2, 129, 4, 2, 22, 2, 130, 131, 132, 71, 6],
#  [296, 22],
#  [296, 22, 48],
#  [53, 297],
#  [53, 297, 39],
#  [53, 297, 39, 298],
#  [53, 297, 39, 298, 28],
#  [53, 297, 39, 298, 28, 133],
#  [53, 297, 39, 298, 28, 133, 8],
#  [53, 297, 39, 298, 28, 133, 8, 23],
#  [53, 297, 39, 298, 28, 133, 8, 23, 6],
#  [53, 297, 39, 298, 28, 133, 8, 23, 6, 134],
#  [53, 297, 39, 298, 28, 133, 8, 23, 6, 134, 8],
#  [53, 299],
#  [53, 299, 39],
#  [53, 299, 39, 42],
#  [53, 299, 39, 42, 31],
#  [53, 299, 39, 42, 31, 300],
#  [53, 299, 39, 42, 31, 300, 133],
#  [53, 299, 39, 42, 31, 300, 133, 8],
#  [53, 299, 39, 42, 31, 300, 133, 8, 23],
#  [53, 299, 39, 42, 31, 300, 133, 8, 23, 10],
#  [53, 299, 39, 42, 31, 300, 133, 8, 23, 10, 135],
#  [53, 299, 39, 42, 31, 300, 133, 8, 23, 10, 135, 70],
#  [53, 299, 39, 42, 31, 300, 133, 8, 23, 10, 135, 70, 8],
#  [53, 301],
#  [53, 301, 302],
#  [53, 301, 302, 43],
#  [53, 301, 302, 43, 75],
#  [53, 301, 302, 43, 75, 10],
#  [53, 301, 302, 43, 75, 10, 32],
#  [53, 301, 302, 43, 75, 10, 32, 12],
#  [53, 301, 302, 43, 75, 10, 32, 12, 31],
#  [53, 301, 302, 43, 75, 10, 32, 12, 31, 303],
#  [53, 301, 302, 43, 75, 10, 32, 12, 31, 303, 8],
#  [53, 301, 302, 43, 75, 10, 32, 12, 31, 303, 8, 23],
#  [53, 304],
#  [53, 304, 305],
#  [53, 304, 305, 75],
#  [53, 304, 305, 75, 10],
#  [53, 304, 305, 75, 10, 127],
#  [53, 304, 305, 75, 10, 127, 52],
#  [53, 304, 305, 75, 10, 127, 52, 17],
#  [18, 13],
#  [18, 13, 40],
#  [18, 13, 40, 18],
#  [18, 13, 40, 18, 13],
#  [18, 13, 40, 18, 13, 40],
#  [18, 13, 40, 18, 13, 40, 44],
#  [18, 13, 40, 18, 13, 40, 44, 49],
#  [18, 13, 40, 18, 13, 40, 44, 49, 306],
#  [18, 13, 40, 18, 13, 40, 44, 49, 306, 4],
#  [18, 13, 40, 18, 13, 40, 44, 49, 306, 4, 2],
#  [18, 13, 40, 18, 13, 40, 44, 49, 306, 4, 2, 307],
#  [13, 25],
#  [13, 25, 8],
#  [13, 25, 8, 33],
#  [13, 25, 8, 33, 3],
#  [13, 25, 8, 33, 3, 16],
#  [13, 25, 8, 33, 3, 16, 308],
#  [13, 25, 8, 33, 3, 16, 308, 2],
#  [13, 25, 8, 33, 3, 16, 308, 2, 309],
#  [13, 25, 8, 33, 3, 16, 308, 2, 309, 45],
#  [13, 25, 8, 33, 3, 16, 308, 2, 309, 45, 3],
#  [13, 25, 8, 33, 3, 16, 308, 2, 309, 45, 3, 2],
#  [13, 25, 8, 33, 3, 16, 308, 2, 309, 45, 3, 2, 25],
#  [13, 25, 8, 33, 3, 16, 308, 2, 309, 45, 3, 2, 25, 310],
#  [13, 25, 8, 33, 3, 16, 308, 2, 309, 45, 3, 2, 25, 310, 311],
#  [6, 2],
#  [6, 2, 14],
#  [6, 2, 14, 45],
#  [6, 2, 14, 45, 312],
#  [6, 2, 14, 45, 312, 5],
#  [6, 2, 14, 45, 312, 5, 18],
#  [6, 2, 14, 45, 312, 5, 18, 313],
#  [6, 2, 14, 45, 312, 5, 18, 313, 16],
#  [6, 2, 14, 45, 312, 5, 18, 313, 16, 136],
#  [6, 2, 14, 45, 312, 5, 18, 313, 16, 136, 314],
#  [315, 43],
#  [315, 43, 137],
#  [315, 43, 137, 138],
#  [315, 43, 137, 138, 139],
#  [315, 43, 137, 138, 139, 3],
#  [315, 43, 137, 138, 139, 3, 2],
#  [315, 43, 137, 138, 139, 3, 2, 25],
#  [315, 43, 137, 138, 139, 3, 2, 25, 6],
#  [315, 43, 137, 138, 139, 3, 2, 25, 6, 138],
#  [315, 43, 137, 138, 139, 3, 2, 25, 6, 138, 140],
#  [315, 43, 137, 138, 139, 3, 2, 25, 6, 138, 140, 139],
#  [315, 43, 137, 138, 139, 3, 2, 25, 6, 138, 140, 139, 141],
#  [315, 43, 137, 138, 139, 3, 2, 25, 6, 138, 140, 139, 141, 37],
#  [316, 317],
#  [316, 317, 10],
#  [316, 317, 10, 34],
#  [316, 317, 10, 34, 26],
#  [316, 317, 10, 34, 26, 142],
#  [316, 317, 10, 34, 26, 142, 42],
#  [316, 317, 10, 34, 26, 142, 42, 15],
#  [316, 317, 10, 34, 26, 142, 42, 15, 143],
#  [316, 317, 10, 34, 26, 142, 42, 15, 143, 8],
#  [52, 7],
#  [52, 7, 144],
#  [52, 7, 144, 18],
#  [52, 7, 144, 18, 13],
#  [52, 7, 144, 18, 13, 40],
#  [52, 7, 144, 18, 13, 40, 145],
#  [52, 7, 144, 18, 13, 40, 145, 17],
#  [52, 7, 144, 18, 13, 40, 145, 17, 3],
#  [52, 7, 144, 18, 13, 40, 145, 17, 3, 318],
#  [52, 7, 144, 18, 13, 40, 145, 17, 3, 318, 21],
#  [52, 7, 144, 18, 13, 40, 145, 17, 3, 318, 21, 11],
#  [76, 66],
#  [76, 66, 3],
#  [76, 66, 3, 5],
#  [76, 66, 3, 5, 319],
#  [76, 66, 3, 5, 319, 320],
#  [76, 66, 3, 5, 319, 320, 146],
#  [76, 66, 3, 5, 319, 320, 146, 93],
#  [76, 66, 3, 5, 319, 320, 146, 93, 15],
#  [76, 66, 3, 5, 319, 320, 146, 93, 15, 321],
#  [142, 23],
#  [142, 23, 3],
#  [142, 23, 3, 147],
#  [142, 23, 3, 147, 322],
#  [142, 23, 3, 147, 322, 34],
#  [18, 77],
#  [18, 77, 28],
#  [18, 77, 28, 13],
#  [18, 77, 28, 13, 25],
#  [18, 77, 28, 13, 25, 5],
#  [18, 77, 28, 13, 25, 5, 18],
#  [18, 77, 28, 13, 25, 5, 18, 77],
#  [18, 77, 28, 13, 25, 5, 18, 77, 7],
#  [18, 77, 28, 13, 25, 5, 18, 77, 7, 5],
#  [18, 77, 28, 13, 25, 5, 18, 77, 7, 5, 8],
#  [18, 77, 28, 13, 25, 5, 18, 77, 7, 5, 8, 33],
#  [18, 77, 28, 13, 25, 5, 18, 77, 7, 5, 8, 33, 30],
#  [323, 2],
#  [323, 2, 14],
#  [323, 2, 14, 3],
#  [323, 2, 14, 3, 14],
#  [323, 2, 14, 3, 14, 324],
#  [323, 2, 14, 3, 14, 324, 325],
#  [323, 2, 14, 3, 14, 324, 325, 326],
#  [323, 2, 14, 3, 14, 324, 325, 326, 148],
#  [323, 2, 14, 3, 14, 324, 325, 326, 148, 149],
#  [323, 2, 14, 3, 14, 324, 325, 326, 148, 149, 20],
#  [323, 2, 14, 3, 14, 324, 325, 326, 148, 149, 20, 5],
#  [13, 25],
#  [13, 25, 37],
#  [13, 25, 37, 327],
#  [13, 25, 37, 327, 10],
#  [13, 25, 37, 327, 10, 32],
#  [13, 25, 37, 327, 10, 32, 72],
#  [13, 25, 37, 327, 10, 32, 72, 4],
#  [13, 25, 37, 327, 10, 32, 72, 4, 5],
#  [13, 25, 37, 327, 10, 32, 72, 4, 5, 150],
#  [13, 25, 37, 327, 10, 32, 72, 4, 5, 150, 328],
#  [13, 25, 37, 327, 10, 32, 72, 4, 5, 150, 328, 4],
#  [151, 2],
#  [151, 2, 18],
#  [151, 2, 18, 136],
#  [151, 2, 18, 136, 329],
#  [151, 2, 18, 136, 329, 2],
#  [151, 2, 18, 136, 329, 2, 68],
#  [151, 2, 18, 136, 329, 2, 68, 6],
#  [151, 2, 18, 136, 329, 2, 68, 6, 330],
#  [151, 2, 18, 136, 329, 2, 68, 6, 330, 151],
#  [331, 332],
#  [331, 332, 1],
#  [331, 332, 1, 333],
#  [331, 332, 1, 333, 42],
#  [331, 332, 1, 333, 42, 334],
#  [331, 332, 1, 333, 42, 334, 5],
#  [331, 332, 1, 333, 42, 334, 5, 335],
#  [331, 332, 1, 333, 42, 334, 5, 335, 336],
#  [58, 18],
#  [58, 18, 123],
#  [58, 18, 123, 44],
#  [58, 18, 123, 44, 152],
#  [58, 18, 123, 44, 152, 3],
#  [58, 18, 123, 44, 152, 3, 34],
#  [58, 18, 123, 44, 152, 3, 34, 26],
#  [58, 18, 123, 44, 152, 3, 34, 26, 5],
#  [58, 18, 123, 44, 152, 3, 34, 26, 5, 143],
#  [337, 4],
#  [337, 4, 8],
#  [337, 4, 8, 7],
#  [337, 4, 8, 7, 338],
#  [337, 4, 8, 7, 338, 21],
#  [337, 4, 8, 7, 338, 21, 11],
#  [337, 4, 8, 7, 338, 21, 11, 3],
#  [337, 4, 8, 7, 338, 21, 11, 3, 78],
#  [337, 4, 8, 7, 338, 21, 11, 3, 78, 339],
#  [337, 4, 8, 7, 338, 21, 11, 3, 78, 339, 340],
#  [337, 4, 8, 7, 338, 21, 11, 3, 78, 339, 340, 15],
#  [337, 4, 8, 7, 338, 21, 11, 3, 78, 339, 340, 15, 341],
#  [337, 4, 8, 7, 338, 21, 11, 3, 78, 339, 340, 15, 341, 146],
#  [3, 342],
#  [3, 342, 73],
#  [153, 28],
#  [153, 28, 13],
#  [153, 28, 13, 25],
#  [153, 28, 13, 25, 153],
#  [153, 28, 13, 25, 153, 343],
#  [153, 28, 13, 25, 153, 343, 10],
#  [153, 28, 13, 25, 153, 343, 10, 344],
#  [153, 28, 13, 25, 153, 343, 10, 344, 345],
#  [153, 28, 13, 25, 153, 343, 10, 344, 345, 77],
#  [153, 28, 13, 25, 153, 343, 10, 344, 345, 77, 7],
#  [153, 28, 13, 25, 153, 343, 10, 344, 345, 77, 7, 5],
#  [346, 8],
#  [346, 8, 33],
#  [346, 8, 33, 30],
#  [346, 8, 33, 30, 347],
#  [346, 8, 33, 30, 347, 154],
#  [346, 8, 33, 30, 347, 154, 1],
#  [346, 8, 33, 30, 347, 154, 1, 155],
#  [346, 8, 33, 30, 347, 154, 1, 155, 38],
#  [346, 8, 33, 30, 347, 154, 1, 155, 38, 348],
#  [346, 8, 33, 30, 347, 154, 1, 155, 38, 348, 156],
#  [148, 149],
#  [148, 149, 20],
#  [148, 149, 20, 5],
#  [148, 149, 20, 5, 13],
#  [148, 149, 20, 5, 13, 25],
#  [148, 149, 20, 5, 13, 25, 37],
#  [148, 149, 20, 5, 13, 25, 37, 349],
#  [148, 149, 20, 5, 13, 25, 37, 349, 350],
#  [148, 149, 20, 5, 13, 25, 37, 349, 350, 3],
#  [148, 149, 20, 5, 13, 25, 37, 349, 350, 3, 76],
#  [148, 149, 20, 5, 13, 25, 37, 349, 350, 3, 76, 8],
#  [148, 149, 20, 5, 13, 25, 37, 349, 350, 3, 76, 8, 38],
#  [2, 351],
#  [2, 351, 1],
#  [2, 351, 1, 352],
#  [2, 351, 1, 352, 156],
#  [2, 351, 1, 352, 156, 79],
#  [2, 351, 1, 352, 156, 79, 353],
#  [2, 351, 1, 352, 156, 79, 353, 145],
#  [2, 351, 1, 352, 156, 79, 353, 145, 17],
#  [2, 351, 1, 352, 156, 79, 353, 145, 17, 3],
#  [2, 351, 1, 352, 156, 79, 353, 145, 17, 3, 354],
#  [26, 150],
#  [26, 150, 1],
#  [26, 150, 1, 355],
#  [26, 150, 1, 355, 8],
#  [26, 150, 1, 355, 8, 356],
#  [26, 150, 1, 355, 8, 356, 7],
#  [26, 150, 1, 355, 8, 356, 7, 157],
#  [26, 150, 1, 355, 8, 356, 7, 157, 21],
#  [26, 150, 1, 355, 8, 356, 7, 157, 21, 11],
#  [26, 150, 1, 355, 8, 356, 7, 157, 21, 11, 3],
#  [357, 358],
#  [357, 358, 3],
#  [357, 358, 3, 17],
#  [357, 358, 3, 17, 15],
#  [357, 358, 3, 17, 15, 76],
#  [357, 358, 3, 17, 15, 76, 5],
#  [357, 358, 3, 17, 15, 76, 5, 359],
#  [357, 358, 3, 17, 15, 76, 5, 359, 360],
#  [357, 358, 3, 17, 15, 76, 5, 359, 360, 4],
#  [357, 358, 3, 17, 15, 76, 5, 359, 360, 4, 8],
#  [357, 358, 3, 17, 15, 76, 5, 359, 360, 4, 8, 3],
#  [80, 4],
#  [80, 4, 54],
#  [80, 4, 54, 81],
#  [80, 4, 54, 81, 46],
#  [80, 4, 54, 81, 46, 80],
#  [80, 4, 54, 81, 46, 80, 361],
#  [80, 4, 54, 81, 46, 80, 361, 362],
#  [80, 4, 54, 81, 46, 80, 361, 362, 158],
#  [363, 137],
#  [363, 137, 54],
#  [363, 137, 54, 81],
#  [363, 137, 54, 81, 51],
#  [363, 137, 54, 81, 51, 364],
#  [363, 137, 54, 81, 51, 364, 365],
#  [363, 137, 54, 81, 51, 364, 365, 366],
#  [363, 137, 54, 81, 51, 364, 365, 366, 6],
#  [363, 137, 54, 81, 51, 364, 365, 366, 6, 2],
#  [367, 368],
#  [367, 368, 4],
#  [367, 368, 4, 2],
#  [367, 368, 4, 2, 369],
#  [367, 368, 4, 2, 369, 16],
#  [367, 368, 4, 2, 369, 16, 370],
#  [367, 368, 4, 2, 369, 16, 370, 7],
#  [367, 368, 4, 2, 369, 16, 370, 7, 371],
#  [367, 368, 4, 2, 369, 16, 370, 7, 371, 3],
#  [367, 368, 4, 2, 369, 16, 370, 7, 371, 3, 372],
#  [373, 36],
#  [373, 36, 374],
#  [373, 36, 374, 52],
#  [373, 36, 374, 52, 1],
#  [373, 36, 374, 52, 1, 375],
#  [373, 36, 374, 52, 1, 375, 122],
#  [46, 80],
#  [46, 80, 79],
#  [46, 80, 79, 7],
#  [46, 80, 79, 7, 376],
#  [46, 80, 79, 7, 376, 10],
#  [46, 80, 79, 7, 376, 10, 135],
#  [46, 80, 79, 7, 376, 10, 135, 70],
#  [46, 80, 79, 7, 376, 10, 135, 70, 377],
#  [46, 80, 79, 7, 376, 10, 135, 70, 377, 1],
#  [19, 378],
#  [19, 378, 379],
#  [82, 4],
#  [82, 4, 54],
#  [82, 4, 54, 81],
#  [82, 4, 54, 81, 46],
#  [82, 4, 54, 81, 46, 82],
#  [82, 4, 54, 81, 46, 82, 7],
#  [82, 4, 54, 81, 46, 82, 7, 2],
#  [82, 4, 54, 81, 46, 82, 7, 2, 134],
#  [4, 380],
#  [4, 380, 83],
#  [4, 380, 83, 159],
#  [4, 380, 83, 159, 4],
#  [4, 380, 83, 159, 4, 381],
#  [4, 380, 83, 159, 4, 381, 46],
#  [4, 380, 83, 159, 4, 381, 46, 51],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140, 383],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140, 383, 7],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140, 383, 7, 384],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140, 383, 7, 384, 3],
#  [4, 380, 83, 159, 4, 381, 46, 51, 382, 159, 4, 2, 140, 383, 7, 384, 3, 69],
#  [4,
#   380,
#   83,
#   159,
#   4,
#   381,
#   46,
#   51,
#   382,
#   159,
#   4,
#   2,
#   140,
#   383,
#   7,
#   384,
#   3,
#   69,
#   385],
#  [4,
#   380,
#   83,
#   159,
#   4,
#   381,
#   46,
#   51,
#   382,
#   159,
#   4,
#   2,
#   140,
#   383,
#   7,
#   384,
#   3,
#   69,
#   385,
#   36],
#  [4,
#   380,
#   83,
#   159,
#   4,
#   381,
#   46,
#   51,
#   382,
#   159,
#   4,
#   2,
#   140,
#   383,
#   7,
#   384,
#   3,
#   69,
#   385,
#   36,
#   386],
#  [4,
#   380,
#   83,
#   159,
#   4,
#   381,
#   46,
#   51,
#   382,
#   159,
#   4,
#   2,
#   140,
#   383,
#   7,
#   384,
#   3,
#   69,
#   385,
#   36,
#   386,
#   387],
#  [4,
#   380,
#   83,
#   159,
#   4,
#   381,
#   46,
#   51,
#   382,
#   159,
#   4,
#   2,
#   140,
#   383,
#   7,
#   384,
#   3,
#   69,
#   385,
#   36,
#   386,
#   387,
#   388],
#  [389, 390],
#  [389, 390, 1],
#  [389, 390, 1, 391],
#  [389, 390, 1, 391, 392],
#  [389, 390, 1, 391, 392, 32],
#  [389, 390, 1, 391, 392, 32, 393],
#  [389, 390, 1, 391, 392, 32, 393, 4],
#  [46, 82],
#  [46, 82, 28],
#  [46, 82, 28, 8],
#  [46, 82, 28, 8, 23],
#  [46, 82, 28, 8, 23, 158],
#  [46, 82, 28, 8, 23, 158, 13],
#  [46, 82, 28, 8, 23, 158, 13, 40],
#  [46, 82, 28, 8, 23, 158, 13, 40, 7],
#  [46, 82, 28, 8, 23, 158, 13, 40, 7, 157],
#  [10, 394],
#  [10, 394, 395],
#  [10, 394, 395, 66],
#  [10, 394, 395, 66, 1],
#  [10, 394, 395, 66, 1, 396],
#  [10, 394, 395, 66, 1, 396, 397],
#  [10, 394, 395, 66, 1, 396, 397, 398],
#  [47, 84],
#  [47, 84, 47],
#  [47, 84, 47, 84],
#  [47, 84, 47, 84, 7],
#  [47, 84, 47, 84, 7, 5],
#  [47, 84, 47, 84, 7, 5, 399],
#  [47, 84, 47, 84, 7, 5, 399, 65],
#  [47, 84, 47, 84, 7, 5, 399, 65, 55],
#  [47, 84, 47, 84, 7, 5, 399, 65, 55, 24],
#  [47, 84, 47, 84, 7, 5, 399, 65, 55, 24, 30],
#  [400, 5],
#  [400, 5, 56],
#  [400, 5, 56, 47],
#  [400, 5, 56, 47, 8],
#  [400, 5, 56, 47, 8, 33],
#  [400, 5, 56, 47, 8, 33, 51],
#  [400, 5, 56, 47, 8, 33, 51, 401],
#  [400, 5, 56, 47, 8, 33, 51, 401, 5],
#  [400, 5, 56, 47, 8, 33, 51, 401, 5, 47],
#  [400, 5, 56, 47, 8, 33, 51, 401, 5, 47, 1],
#  [400, 5, 56, 47, 8, 33, 51, 401, 5, 47, 1, 402],
#  [403, 2],
#  [403, 2, 404],
#  [403, 2, 404, 405],
#  [403, 2, 404, 405, 47],
#  [403, 2, 404, 405, 47, 84],
#  [403, 2, 404, 405, 47, 84, 406],
#  [403, 2, 404, 405, 47, 84, 406, 32],
#  [403, 2, 404, 405, 47, 84, 406, 32, 55],
#  [403, 2, 404, 405, 47, 84, 406, 32, 55, 20],
#  [5, 407],
#  [5, 407, 74],
#  [5, 407, 74, 408],
#  [5, 407, 74, 408, 16],
#  [5, 407, 74, 408, 16, 24],
#  [5, 407, 74, 408, 16, 24, 7],
#  [5, 407, 74, 408, 16, 24, 7, 409],
#  [5, 407, 74, 408, 16, 24, 7, 409, 410],
#  [5, 407, 74, 408, 16, 24, 7, 409, 410, 3],
#  [5, 407, 74, 408, 16, 24, 7, 409, 410, 3, 34],
#  [26, 5],
#  [26, 5, 411],
#  [26, 5, 411, 55],
#  [26, 5, 411, 55, 58],
#  [26, 5, 411, 55, 58, 7],
#  [26, 5, 411, 55, 58, 7, 412],
#  [26, 5, 411, 55, 58, 7, 412, 413],
#  [26, 5, 411, 55, 58, 7, 412, 413, 21],
#  [26, 5, 411, 55, 58, 7, 412, 413, 21, 11],
#  [26, 5, 411, 55, 58, 7, 412, 413, 21, 11, 3],
#  [26, 5, 411, 55, 58, 7, 412, 413, 21, 11, 3, 414],
#  [26, 5, 411, 55, 58, 7, 412, 413, 21, 11, 3, 414, 73],
#  [15, 147],
#  [15, 147, 74],
#  [15, 147, 74, 17],
#  [56, 12],
#  [56, 12, 41],
#  [56, 12, 41, 56],
#  [56, 12, 41, 56, 12],
#  [56, 12, 41, 56, 12, 41],
#  [56, 12, 41, 56, 12, 41, 44],
#  [56, 12, 41, 56, 12, 41, 44, 415],
#  [56, 12, 41, 56, 12, 41, 44, 415, 8],
#  [56, 12, 41, 56, 12, 41, 44, 415, 8, 23],
#  [26, 83],
#  [26, 83, 45],
#  [26, 83, 45, 416],
#  [26, 83, 45, 416, 38],
#  [26, 83, 45, 416, 38, 417],
#  [26, 83, 45, 416, 38, 417, 54],
#  [26, 83, 45, 416, 38, 417, 54, 418],
#  [26, 83, 45, 416, 38, 417, 54, 418, 2],
#  [26, 83, 45, 416, 38, 417, 54, 418, 2, 419],
#  [26, 83, 45, 416, 38, 417, 54, 418, 2, 419, 160],
#  [26, 83, 45, 416, 38, 417, 54, 418, 2, 419, 160, 161],
#  [26, 83, 45, 416, 38, 417, 54, 418, 2, 419, 160, 161, 162],
#  [420, 163],
#  [420, 163, 2],
#  [420, 163, 2, 45],
#  [420, 163, 2, 45, 421],
#  [420, 163, 2, 45, 421, 2],
#  [420, 163, 2, 45, 421, 2, 422],
#  [420, 163, 2, 45, 421, 2, 422, 160],
#  [420, 163, 2, 45, 421, 2, 422, 160, 161],
#  [420, 163, 2, 45, 421, 2, 422, 160, 161, 162],
#  [420, 163, 2, 45, 421, 2, 422, 160, 161, 162, 423],
#  [420, 163, 2, 45, 421, 2, 422, 160, 161, 162, 423, 163],
#  [420, 163, 2, 45, 421, 2, 422, 160, 161, 162, 423, 163, 2],
#  [45, 42],
#  [45, 42, 31],
#  [45, 42, 31, 56],
#  [45, 42, 31, 56, 12],
#  [45, 42, 31, 56, 12, 41],
#  [45, 42, 31, 56, 12, 41, 424],
#  [45, 42, 31, 56, 12, 41, 424, 154],
#  [45, 42, 31, 56, 12, 41, 424, 154, 155],
#  [425, 1],
#  [425, 1, 43],
#  [425, 1, 43, 114],
#  [425, 1, 43, 114, 41],
#  [425, 1, 43, 114, 41, 44],
#  [425, 1, 43, 114, 41, 44, 152],
#  [425, 1, 43, 114, 41, 44, 152, 3],
#  [425, 1, 43, 114, 41, 44, 152, 3, 34],
#  [425, 1, 43, 114, 41, 44, 152, 3, 34, 26],
#  [426, 5],
#  [426, 5, 427],
#  [426, 5, 427, 428],
#  [426, 5, 427, 428, 1],
#  [426, 5, 427, 428, 1, 32],
#  [426, 5, 427, 428, 1, 32, 12],
#  [426, 5, 427, 428, 1, 32, 12, 42],
#  [426, 5, 427, 428, 1, 32, 12, 42, 44],
#  [426, 5, 427, 428, 1, 32, 12, 42, 44, 429],
#  [21, 11],
#  [21, 11, 3],
#  [21, 11, 3, 430],
#  [21, 11, 3, 430, 431],
#  [21, 11, 3, 430, 431, 15],
#  [21, 11, 3, 430, 431, 15, 432],
#  [21, 11, 3, 430, 431, 15, 432, 433],
#  [21, 11, 3, 430, 431, 15, 432, 433, 3],
#  [21, 11, 3, 430, 431, 15, 432, 433, 3, 434],
#  [85, 14],
#  [85, 14, 12],
#  [85, 14, 12, 164],
#  [85, 14, 12, 164, 85],
#  [85, 14, 12, 164, 85, 14],
#  [85, 14, 12, 164, 85, 14, 12],
#  [85, 14, 12, 164, 85, 14, 12, 7],
#  [85, 14, 12, 164, 85, 14, 12, 7, 5],
#  [85, 14, 12, 164, 85, 14, 12, 7, 5, 57],
#  [85, 14, 12, 164, 85, 14, 12, 7, 5, 57, 43],
#  [24, 30],
#  [24, 30, 165],
#  [24, 30, 165, 435],
#  [24, 30, 165, 435, 436],
#  [24, 30, 165, 435, 436, 38],
#  [24, 30, 165, 435, 436, 38, 2],
#  [24, 30, 165, 435, 436, 38, 2, 437],
#  [24, 30, 165, 435, 436, 38, 2, 437, 86],
#  [24, 30, 165, 435, 436, 38, 2, 437, 86, 166],
#  [24, 30, 165, 435, 436, 38, 2, 437, 86, 166, 438],
#  [24, 30, 165, 435, 436, 38, 2, 437, 86, 166, 438, 31],
#  [24, 30, 165, 435, 436, 38, 2, 437, 86, 166, 438, 31, 6],
#  [2, 439],
#  [2, 439, 440],
#  [2, 439, 440, 16],
#  [2, 439, 440, 16, 24],
#  [2, 439, 440, 16, 24, 7],
#  [2, 439, 440, 16, 24, 7, 441],
#  [2, 439, 440, 16, 24, 7, 441, 3],
#  [2, 439, 440, 16, 24, 7, 441, 3, 17],
#  [2, 439, 440, 16, 24, 7, 441, 3, 17, 21],
#  [2, 439, 440, 16, 24, 7, 441, 3, 17, 21, 11],
#  [2, 439, 440, 16, 24, 7, 441, 3, 17, 21, 11, 442],
#  [78, 59],
#  [78, 59, 443],
#  [78, 59, 443, 444],
#  [78, 59, 443, 444, 445],
#  [78, 59, 443, 444, 445, 1],
#  [78, 59, 443, 444, 445, 1, 78],
#  [78, 59, 443, 444, 445, 1, 78, 446],
#  [78, 59, 443, 444, 445, 1, 78, 446, 447],
#  [164, 79],
#  [164, 79, 121],
#  [164, 79, 121, 2],
#  [164, 79, 121, 2, 85],
#  [164, 79, 121, 2, 85, 4],
#  [164, 79, 121, 2, 85, 4, 5],
#  [164, 79, 121, 2, 85, 4, 5, 57],
#  [164, 79, 121, 2, 85, 4, 5, 57, 141],
#  [164, 79, 121, 2, 85, 4, 5, 57, 141, 37],
#  [164, 79, 121, 2, 85, 4, 5, 57, 141, 37, 448],
#  [164, 79, 121, 2, 85, 4, 5, 57, 141, 37, 448, 10],
#  [164, 79, 121, 2, 85, 4, 5, 57, 141, 37, 448, 10, 34],
#  [26, 5],
#  [26, 5, 449],
#  [26, 5, 449, 450],
#  [26, 5, 449, 450, 4],
#  [26, 5, 449, 450, 4, 2],
#  [26, 5, 449, 450, 4, 2, 33],
#  [26, 5, 449, 450, 4, 2, 33, 7],
#  [26, 5, 449, 450, 4, 2, 33, 7, 144],
#  [86, 14],
#  [86, 14, 12],
#  [86, 14, 12, 167],
#  [86, 14, 12, 167, 86],
#  [86, 14, 12, 167, 86, 14],
#  [86, 14, 12, 167, 86, 14, 12],
#  [86, 14, 12, 167, 86, 14, 12, 7],
#  [86, 14, 12, 167, 86, 14, 12, 7, 5],
#  [86, 14, 12, 167, 86, 14, 12, 7, 5, 57],
#  [86, 14, 12, 167, 86, 14, 12, 7, 5, 57, 43],
#  [86, 14, 12, 167, 86, 14, 12, 7, 5, 57, 43, 24],
#  [30, 165],
#  [30, 165, 11],
#  [30, 165, 11, 451],
#  [30, 165, 11, 451, 11],
#  [30, 165, 11, 451, 11, 452],
#  [30, 165, 11, 451, 11, 452, 453],
#  [30, 165, 11, 451, 11, 452, 453, 83],
#  [30, 165, 11, 451, 11, 452, 453, 83, 454],
#  [30, 165, 11, 451, 11, 452, 453, 83, 454, 166],
#  [30, 165, 11, 451, 11, 452, 453, 83, 454, 166, 455],
#  [30, 165, 11, 451, 11, 452, 453, 83, 454, 166, 455, 167],
#  [7, 456],
#  [7, 456, 3],
#  [7, 456, 3, 69],
#  [7, 456, 3, 69, 17],
#  [7, 456, 3, 69, 17, 36],
#  [7, 456, 3, 69, 17, 36, 457],
#  [7, 456, 3, 69, 17, 36, 457, 458],
#  [7, 456, 3, 69, 17, 36, 457, 458, 459],
#  [7, 456, 3, 69, 17, 36, 457, 458, 459, 55],
#  [1, 460],
#  [1, 460, 461],
#  [1, 460, 461, 3],
#  [1, 460, 461, 3, 126],
#  [1, 460, 461, 3, 126, 16],
#  [1, 460, 461, 3, 126, 16, 24],
#  [1, 460, 461, 3, 126, 16, 24, 462],
#  [1, 460, 461, 3, 126, 16, 24, 462, 463],
#  [1, 460, 461, 3, 126, 16, 24, 462, 463, 464],
#  [1, 460, 461, 3, 126, 16, 24, 462, 463, 464, 2],
#  [33, 4],
#  [33, 4, 5],
#  [33, 4, 5, 57],
#  [33, 4, 5, 57, 1],
#  [33, 4, 5, 57, 1, 7],
#  [33, 4, 5, 57, 1, 7, 465],
#  [33, 4, 5, 57, 1, 7, 465, 466],
#  [33, 4, 5, 57, 1, 7, 465, 466, 65],
#  [33, 4, 5, 57, 1, 7, 465, 466, 65, 31],
#  [33, 4, 5, 57, 1, 7, 465, 466, 65, 31, 118],
#  [33, 4, 5, 57, 1, 7, 465, 466, 65, 31, 118, 89]]

# %%
#input is of different size so make it same size by padding
max_len=max([len(x) for x in input_sequ])
max_len
# Out:
# 23

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
paded_input_sequences=pad_sequences(input_sequ,maxlen=max_len,padding='pre')
paded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  87,  48],
#        [  0,   0,   0, ...,  87,  48, 168],
#        [  0,   0,   0, ...,   0, 169,   9],
#        ...,
#        [  0,   0,   0, ..., 466,  65,  31],
#        [  0,   0,   0, ...,  65,  31, 118],
#        [  0,   0,   0, ...,  31, 118,  89]], dtype=int32)

# %%
X=paded_input_sequences[:,:-1]
y=paded_input_sequences[:,-1]

# %%
print(X.shape)
print(y.shape)
# Out:
# (992, 22)
# (992,)

# %%
#it is a multi class classification so go for one-hot encoding
from tensorflow.keras.utils import to_categorical
y=to_categorical(y,num_classes=len(tokenizer.word_index)+1)

# %%
y.shape
# Out:
# (992, 467)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense
max_len = max([len(x) for x in input_sequ])
model=Sequential()
vocab_size = len(tokenizer.word_index) + 1
model.add(Embedding(vocab_size, 100, input_length=max_len-1))
# model.add(Embedding(283,100,input_length=max_len-1))
model.add(LSTM(150))
model.add(Dense(len(tokenizer.word_index)+1,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.build(input_shape=(None, max_len-1))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, 22, 100)        │        46,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 467)            │        70,517 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 267,817 (1.02 MB)
#  Trainable params: 267,817 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(len(input_sequ))
print(max_len)
# Out:
# 992
# 23

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.0478 - loss: 6.0592
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.0462 - loss: 5.6104
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.0492 - loss: 5.5532
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0668 - loss: 5.4184
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.0572 - loss: 5.4457
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.0662 - loss: 5.3593
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.0593 - loss: 5.3044
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.0753 - loss: 5.0914
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.0848 - loss: 4.9852
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1020 - loss: 4.8008
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1303 - loss: 4.5556
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.1354 - loss: 4.4155
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.1705 - loss: 4.2091
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.1978 - loss: 4.0604
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2352 - loss: 3.8366
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.2643 - loss: 3.6412
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.3006 - loss: 3.4595
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3576 - loss: 3.2294
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3754 - loss: 3.0594
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4576 - loss: 2.7418
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4827 - loss: 2.6230
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5177 - loss: 2.5421
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.5446 - loss: 2.3367
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6028 - loss: 2.1606
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6353 - loss: 2.0801
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6906 - loss: 1.9139
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7280 - loss: 1.7419
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7390 - loss: 1.6642
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7897 - loss: 1.5242
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7983 - loss: 1.4522
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8399 - loss: 1.3129
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8615 - loss: 1.1651
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8820 - loss: 1.1062
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8851 - loss: 1.0597
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8949 - loss: 0.9913
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9238 - loss: 0.9072
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9257 - loss: 0.8402
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9398 - loss: 0.7629
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9405 - loss: 0.7272
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9582 - loss: 0.6460
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9426 - loss: 0.6299
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9663 - loss: 0.5743
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9617 - loss: 0.5537
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9635 - loss: 0.5042
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9612 - loss: 0.4806
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9703 - loss: 0.4370
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9698 - loss: 0.4167
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9638 - loss: 0.4289
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9798 - loss: 0.3540
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9658 - loss: 0.3665
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9733 - loss: 0.3350
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9638 - loss: 0.3287
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9682 - loss: 0.3099
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9824 - loss: 0.2859
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9754 - loss: 0.2670
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9737 - loss: 0.2594
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9821 - loss: 0.2379
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9790 - loss: 0.2247
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9601 - loss: 0.2548
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9764 - loss: 0.2193
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9696 - loss: 0.2078
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9725 - loss: 0.1925
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9750 - loss: 0.1864
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9714 - loss: 0.1795
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9687 - loss: 0.1797
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9715 - loss: 0.1832
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9769 - loss: 0.1597
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9744 - loss: 0.1544
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9744 - loss: 0.1461
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9707 - loss: 0.1489
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9845 - loss: 0.1366
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9643 - loss: 0.1435
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9695 - loss: 0.1326
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9720 - loss: 0.1341
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9738 - loss: 0.1283
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9767 - loss: 0.1219
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9742 - loss: 0.1203
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9856 - loss: 0.1069
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9538 - loss: 0.1293
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9707 - loss: 0.1144
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9796 - loss: 0.1015
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9684 - loss: 0.1129
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9701 - loss: 0.1051
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9714 - loss: 0.1002
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9715 - loss: 0.1006
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9784 - loss: 0.0894
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9697 - loss: 0.0918
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9664 - loss: 0.0958
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9791 - loss: 0.0848
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9685 - loss: 0.1021
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9580 - loss: 0.1014
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9832 - loss: 0.0798
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9720 - loss: 0.0881
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9784 - loss: 0.0775
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9705 - loss: 0.0879
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9719 - loss: 0.0846
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9728 - loss: 0.0800
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9783 - loss: 0.0692
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9815 - loss: 0.0704
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9701 - loss: 0.0800

# %%
import time
import numpy as np
text = "program"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=max([len(x) for x in input_sequ]), padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# program outcomes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# program outcomes pos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# program outcomes pos node
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# program outcomes pos node operations
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# program outcomes pos node operations on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# program outcomes pos node operations on non
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# program outcomes pos node operations on non linear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# program outcomes pos node operations on non linear data
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# program outcomes pos node operations on non linear data structures
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# program outcomes pos node operations on non linear data structures for
